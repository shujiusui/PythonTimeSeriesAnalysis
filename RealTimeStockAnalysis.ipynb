# %%
import pandas_datareader as pd
import numpy as np
#import datetime
from plotly.offline import plot, init_notebook_mode
import cufflinks as cf
from yahoo_fin import stock_info
#init_notebook_mode()

# Reference https://thecleverprogrammer.com/2020/08/22/real-time-stock-price-with-python/

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = {}
data['AAPL'] = stock_info.get_data('AAPL', start_date='01-01-2022',  end_date='03-24-2022')
print(data['AAPL'].head())
print(data["AAPL"])
# Out:
#                   open        high         low       close    adjclose  \
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  181.778397
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  179.471344
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  174.697418
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  171.781143
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  171.950928
#
#                volume ticker
# 2022-01-03  104487900   AAPL
# 2022-01-04   99310400   AAPL
# 2022-01-05   94537600   AAPL
# 2022-01-06   96904000   AAPL
# 2022-01-07   86709100   AAPL
#                   open        high         low       close    adjclose  \
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  181.778397
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  179.471344
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  174.697418
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  171.781143
# ...

# %%
print(stock_info.get_live_price('AAPL'))
# Out:
# 174.07000732421875

# %%
qf = cf.QuantFig(data["AAPL"])
qf.add_bollinger_bands()
qf.add_macd()
qf.iplot()
# Out:
# <div>                            <div id="bf859dd3-4460-4775-8e9e-81a3b1af5050" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df=cf.datagen.ohlc()
qf=cf.QuantFig(df,title='First Quant Figure',legend='top',name='GS')
qf.add_bollinger_bands()
qf.iplot()
# Out:
# <div>                            <div id="99bbac40-eeaa-464b-8fb0-d82236b34b54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
aapl['Close'].plot(grid=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
adj_close_px = aapl['Close']

# %%
moving_avg = adj_close_px.rolling(window=5).mean()

# %%
moving_avg.plot(grid=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
aapl['5'] =
